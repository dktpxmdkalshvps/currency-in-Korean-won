# %%
print (12)
# Out:
# 12

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Using cached yfinance-1.1.0-py2.py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\user\.conda\envs\myenv\lib\site-packages (from yfinance) (3.0.0)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\user\.conda\envs\myenv\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: requests>=2.31 in c:\users\user\.conda\envs\myenv\lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\user\.conda\envs\myenv\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\user\.conda\envs\myenv\lib\site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\user\.conda\envs\myenv\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\user\.conda\envs\myenv\lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\user\.conda\envs\myenv\lib\site-packages (from yfinance) (3.19.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\user\.conda\envs\myenv\lib\site-packages (from yfinance) (4.14.3)
# Collecting curl_cffi<0.14,>=0.7 (from yfinance)
#   Using cached curl_cffi-0.13.0-cp39-abi3-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\user\.conda\envs\myenv\lib\site-packages (from yfinance) (6.33.5)
# Requirement already satisfied: websockets>=13.0 in c:\users\user\.conda\envs\myenv\lib\site-packages (from yfinance) (16.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\user\.conda\envs\myenv\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\user\.conda\envs\myenv\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.1.4)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\user\.conda\envs\myenv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\user\.conda\envs\myenv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: pycparser in c:\users\user\.conda\envs\myenv\lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\.conda\envs\myenv\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\user\.conda\envs\myenv\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\.conda\envs\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\.conda\envs\myenv\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\.conda\envs\myenv\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\.conda\envs\myenv\lib\site-packages (from requests>=2.31->yfinance) (2.6.3)
# Using cached yfinance-1.1.0-py2.py3-none-any.whl (129 kB)
# Using cached curl_cffi-0.13.0-cp39-abi3-win_amd64.whl (1.6 MB)
# Installing collected packages: curl_cffi, yfinance
#
#    ---------------------------------------- 0/2 [curl_cffi]
#    ---------------------------------------- 0/2 [curl_cffi]
#    ---------------------------------------- 0/2 [curl_cffi]
#    -------------------- ------------------- 1/2 [yfinance]
#    -------------------- ------------------- 1/2 [yfinance]
#    -------------------- ------------------- 1/2 [yfinance]
#    -------------------- ------------------- 1/2 [yfinance]
#    -------------------- ------------------- 1/2 [yfinance]
#    ---------------------------------------- 2/2 [yfinance]
#
# Successfully installed curl_cffi-0.13.0 yfinance-1.1.0

# %%
# !pip install requests
# Out:
# Collecting requests
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl (106 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached certifi-2026.1.4-py3-none-any.whl (152 kB)
# Installing collected packages: urllib3, idna, charset_normalizer, certifi, requests
#
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    -------- ------------------------------- 1/5 [idna]
#    -------- ------------------------------- 1/5 [idna]
#    ---------------- ----------------------- 2/5 [charset_normalizer]
#    ---------------- ----------------------- 2/5 [charset_normalizer]
#    ------------------------ --------------- 3/5 [certifi]
#    -------------------------------- ------- 4/5 [requests]
#    -------------------------------- ------- 4/5 [requests]
#    ---------------------------------------- 5/5 [requests]
#
# Successfully installed certifi-2026.1.4 charset_normalizer-3.4.4 idna-3.11 requests-2.32.5 urllib3-2.6.3

# %%
import yfinance as yf

def get_exchange_rates_yf():
    # Symbols mapping
    symbols = {
        "USD/KRW": "USDKRW=X",
        "EUR/KRW": "EURKRW=X",
        "JPY/KRW": "JPYKRW=X"
    }
    
    print(f"{'Currency':<12} | {'Rate (KRW)':<10}")
    print("-" * 30)

    for name, ticker_symbol in symbols.items():
        try:
            ticker = yf.Ticker(ticker_symbol)
            # Fetching the last price directly
            current_rate = ticker.fast_info['last_price']
            
            # Handling NaN or errors
            if current_rate is None or str(current_rate) == 'nan':
                hist = ticker.history(period="1d")
                current_rate = hist['Close'].iloc[-1]

            # Display Logic
            if "JPY" in name:
                # Multiply by 100 and label as 100¥
                print(f"{'JPY (100¥)':<12} | {current_rate * 100:,.2f}")
            else:
                print(f"{name:<12} | {current_rate:,.2f}")
                
        except Exception:
            print(f"{name:<12} | Error fetching data")

if __name__ == "__main__":
    get_exchange_rates_yf()
# Out:
# Currency     | Rate (KRW)
# ------------------------------
# USD/KRW      | 1,455.28
# EUR/KRW      | 1,732.70
# JPY (100¥)   | 945.30
